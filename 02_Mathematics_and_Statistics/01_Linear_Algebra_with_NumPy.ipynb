# %%
import numpy as np

# %%
s = 5
s
# Out:
# 5

# %%
v = np.array([5,-2,4])
v
# Out:
# array([ 5, -2,  4])

# %%
m = np.array([[5,12,6],[-3,0,14]])
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
type(s)
# Out:
# int

# %%
type(v)
# Out:
# numpy.ndarray

# %%
type(m)
# Out:
# numpy.ndarray

# %%
s_array = np.array(5)
s_array
# Out:
# array(5)

# %%
v.shape
# Out:
# (3,)

# %%
m.shape
# Out:
# (2, 3)

# %%
s.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2157139140.py in <cell line: 0>()
# ----> 1 s.shape
#
# AttributeError: 'int' object has no attribute 'shape'

# %%
# テンソルの作成　行列の集まりと考えることができる

# %%
m1 = np.array([[5,12,6],[-3,0,14]])

# %%
m1
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
m2 = np.array([[9,7,6],[1,34,0]])
m2
# Out:
# array([[ 9,  7,  6],
#        [ 1, 34,  0]])

# %%
t = np.array([m1,m2])
t
# Out:
# array([[[ 5, 12,  6],
#         [-3,  0, 14]],
#
#        [[ 9,  7,  6],
#         [ 1, 34,  0]]])

# %%
t.shape
# Out:
# (2, 2, 3)

# %%
t_manual = np.array([[[5,23,45],[-3,0,14]],[[9,8,7],[1,4,33]]])
t_manual
# Out:
# array([[[ 5, 23, 45],
#         [-3,  0, 14]],
#
#        [[ 9,  8,  7],
#         [ 1,  4, 33]]])

# %%
# 足し算、引き算

# %%
m1=np.array([[5,12,6],[-3,0,14]])
m2=np.array([[9,8,7],[1,3,-5]])

# %%
m1 + m2
# Out:
# array([[14, 20, 13],
#        [-2,  3,  9]])

# %%
m3 = np.array([[5,3],[-2,4]])
m4 = np.array([[7,-5],[3,8]])

# %%
m3 - m4
# Out:
# array([[-2,  8],
#        [-5, -4]])

# %%
m5 = np.array([[22.33,-4.73],[-203.14,1200.02],[4.22,234.1]])
m6 = np.array([[233,45],[44,6767],[232,454]])

# %%
m5-m6
# Out:
# array([[ -210.67,   -49.73],
#        [ -247.14, -5566.98],
#        [ -227.78,  -219.9 ]])

# %%
v2 = np.array([1,2,3,4,5])
v1 = np.array([5,4,3,2,1])

# %%
v1+v2
# Out:
# array([6, 6, 6, 6, 6])

# %%
v1-v2
# Out:
# array([ 4,  2,  0, -2, -4])

# %%
# Error

# %%
5+5
# Out:
# 10

# %%
198-34
# Out:
# 164

# %%
m1 = np.array([[5,12,6],[-3,0,14]])
m2 = np.array([[5,3],[-2,4]])

# %%
m2+m1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3224064169.py in <cell line: 0>()
# ----> 1 m2+m1
#
# ValueError: operands could not be broadcast together with shapes (2,2) (2,3)

# %%
v1 = np.array([1,2,3,4,5])
v2 = np.array([1,2,3])

# %%
v1+v2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1550407469.py in <cell line: 0>()
# ----> 1 v1+v2
#
# ValueError: operands could not be broadcast together with shapes (5,) (3,)

# %%
m1
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
# 数学上はできないけど、プログラミング上で演算できる
m1 +1
# Out:
# array([[ 6, 13,  7],
#        [-2,  1, 15]])

# %%
v1+3
# Out:
# array([4, 5, 6, 7, 8])

# %%
m1 + np.array([1])
# Out:
# array([[ 6, 13,  7],
#        [-2,  1, 15]])

# %%
v1+np.array([1])
# Out:
# array([2, 3, 4, 5, 6])

# %%
# 転置

# %%
A = np.array([[5,12,6],[-3,0,14]])

# %%
A
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
A.T
# Out:
# array([[ 5, -3],
#        [12,  0],
#        [ 6, 14]])

# %%
B = np.array([[5,3],[-2,4]])
B
# Out:
# array([[ 5,  3],
#        [-2,  4]])

# %%
B.T
# Out:
# array([[ 5, -2],
#        [ 3,  4]])

# %%
C = np.array([[4,-5],[8,12],[-2,-3],[19,0]])
C
# Out:
# array([[ 4, -5],
#        [ 8, 12],
#        [-2, -3],
#        [19,  0]])

# %%
C.T
# Out:
# array([[ 4,  8, -2, 19],
#        [-5, 12, -3,  0]])

# %%
s = np.array([5])
s
# Out:
# array([5])

# %%
s.T
# Out:
# array([5])

# %%
x = np.array([1,2,3])
x
# Out:
# array([1, 2, 3])

# %%
x.T
# Out:
# array([1, 2, 3])

# %%
x.shape
# Out:
# (3,)

# %%
x_reshaped = x.reshape(1,3)
x_reshaped
# Out:
# array([[1, 2, 3]])

# %%
x_reshaped.T
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
# ドット積、スカラー積

# %%
x = np.array([2,8,-4])
y = np.array([1,-7,3])

# %%
np.dot(x,y)
# Out:
# np.int64(-66)

# %%
u = np.array([0,2,5,8])
v = np.array([20,3,4,-1])

# %%
np.dot(u,v)
# Out:
# np.int64(18)

# %%
np.dot(5,6)
# Out:
# np.int64(30)

# %%
x
# Out:
# array([ 2,  8, -4])

# %%
5*x
# Out:
# array([ 10,  40, -20])

# %%
x*4
# Out:
# array([  8,  32, -16])

# %%
A  = np.array([[5,12,6],[-3,0,14]])
B = np.array([[2,-1],[8,0],[3,0]])

# %%
A
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
B
# Out:
# array([[ 2, -1],
#        [ 8,  0],
#        [ 3,  0]])

# %%
np.dot(A,B)
# Out:
# array([[124,  -5],
#        [ 36,   3]])

# %%
C  = np.array([[-12,5,-5,1,6],[6,-2,0,0,-3],[10,2,0,8,0],[9,-4,8,3,-6]])
D = np.array([[6,-1],[8,-4],[2,-2],[7,4],[-6,-9]])

# %%
C
# Out:
# array([[-12,   5,  -5,   1,   6],
#        [  6,  -2,   0,   0,  -3],
#        [ 10,   2,   0,   8,   0],
#        [  9,  -4,   8,   3,  -6]])

# %%
D
# Out:
# array([[ 6, -1],
#        [ 8, -4],
#        [ 2, -2],
#        [ 7,  4],
#        [-6, -9]])

# %%
np.dot(C,D)
# Out:
# array([[-71, -48],
#        [ 38,  29],
#        [132,  14],
#        [ 95,  57]])
