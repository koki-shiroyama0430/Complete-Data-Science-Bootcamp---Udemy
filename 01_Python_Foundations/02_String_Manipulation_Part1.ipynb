# %%
x = "Python"
print(x[1])
# Out:
# y

# %%
x = 'Python'
print(x[0:2])
# Out:
# Py

# %%
x = 'Python'
print('x[2:5], x[2:5])
# Out:
#   File "/tmp/ipython-input-3-3101075047.py", line 2
#     print('x[2:5], x[2:5])
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
x = 'Python'
print('x[2:5]', x[2:5])
# Out:
# x[2:5] tho

# %%
x = 'Python'
print('x[2:5] = ', x[2:5])
# Out:
# x[2:5] =  tho

# %%
x = 'Python'
print('x[2:5]', x[:5])
# Out:
# x[2:5] Pytho
