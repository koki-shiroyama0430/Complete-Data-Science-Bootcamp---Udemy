# %%
if 5 == 15 / 3:
  print('Hooray!')
# Out:
# Hooray!

# %%
if 5 == 18 / 3:
  print('Hooray!')

# %%
if 5 != 3 * 6:
  print('Hooray!')
# Out:
# Hooray!

# %%
x  = 1

if x > 3:
  print('Case 1')
if x <= 3:
  print('Case 2')
# Out:
# Case 2

# %%
x = 1

if x > 3:
  print('Case 1')
else:
  print('Case 2')
# Out:
# Case 2

# %%
x = 1

if x > 3:
  print('Case 1')
  else:
    print('Case 2')
# Out:
#   File "/tmp/ipython-input-2627104322.py", line 5
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
def compare_to_five(y):
  if y > 5:
    return ('Greater')
  elif y < 5:
    return('less')
  else:
    return('Equal')

# %%
print(compare_to_five(10))
# Out:
# Greater

# %%
print(compare_to_five(3))
# Out:
# less

# %%
print(compare_to_five(5))
# Out:
# Equal

# %%
def compare_to_five(y):
  if y > 5:
    return('Greater')
  elif y < 5:
    return('Less')
  elif y < 0:
    return('Negative')
  else:
    return('Equal')

# %%
print(compare_to_five(-23))
# Out:
# Less

# %%
def compare_to_five(y):
  if y > 5:
    return('Greater')
  elif y < 0:
    return('Negative')
  elif y < 5:
    return('Less')
  else:
    return('Equal')

# %%
print(compare_to_five(-23))
# Out:
# Negative

# %% [markdown]
# ブール値

# %%
x = 2

if x > 4:
  print('Correct')
else:
  print('Incorrect')
# Out:
# Incorrect
