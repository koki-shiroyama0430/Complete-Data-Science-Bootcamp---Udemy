# %%
print('"Hello, World"')
# Out:
# "Hello, World"

# %%
print(1)
# Out:
# 1

# %%
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
print(123,"Hello")
# Out:
# 123 Hello

# %%
print(1)
#print(2)
print(3)
# Out:
# 1
# 3

# %%
"""
print(1)
print(2)
print(3)
"""
# Out:
# '\nprint(1)\nprint(2)\nprint(3)\n'

# %%
"Hello"
# Out:
# 'Hello'

# %%
x = 10
print(x)
# Out:
# 10

# %%
x = 1 + 2
print(x)
# Out:
# 3

# %%
print("1" + "2")
# Out:
# 12

# %%
x = "1" + "2"
print(x)
# Out:
# 12

# %%
x = '1' + '2'

# %%
print(x)
# Out:
# 12

# %%
print(str(10))
print(int('10'))
# Out:
# 10
# 10

# %%
a = 1
b = 2
x = str(a) + str(b)
print(x)
# Out:
# 12

# %%
print('1\n2\n3')
# Out:
# 1
# 2
# 3

# %%
print('1\n2\n3')
# Out:
# 1
# 2
# 3

# %%
print('23\r5')
# Out:
# 5

# %%
print('"43"')
# Out:
# "43"

# %%
print("\"")
# Out:
# "

# %%
print("キャリッジリターン : Hello\rWorld!")
# Out:
# World!

# %%
import time

for i in range(10):
    print("\r読み込み中...", i * 10, "%", end="")
    time.sleep(0.5)
print("\r読み込み完了！     ")
# Out:
# 読み込み完了！

# %%
print("キャリッジリターン : Hello World!")
# Out:
# キャリッジリターン : Hello World!

# %%
print("キャリッジリターン : Hello\rWorld!")
# Out:
# World!

# %%
print("改行 : Hello\nWorld!")
# Out:
# 改行 : Hello
# World!

# %%
print("タブ : Hello\tWorld!")
# Out:
# タブ : Hello	World!

# %%
print("バックスペース : Hello\bWorld!")
# Out:
# World!

# %%
print("フォームフィード : Hello\fWorld")
# Out:
# フォームフィード : HelloWorld

# %%
print("垂直タブ : Hello\vWorld")
# Out:
# 垂直タブ : HelloWorld

# %%
print("バックスラッシュ : Hello\\World")
# Out:
# バックスラッシュ : Hello\World

# %%
print("シングルクォート : It\'s Python")
# Out:
# シングルクォート : It's Python

# %%
print("ダブルクォート : She said \"Hello\"")
# Out:
# ダブルクォート : She said "Hello"

# %%
print("16進数コード : \x41\x42\x43")
# Out:
# 16進数コード : ABC

# %%
print("8進数 : \101")
# Out:
# 8進数 : A

# %%
print("Unicode: \u03A9")
# Out:
# Unicode: Ω

# %%
print("Unicode絵文字 : \U0001F600")
# Out:
# Unicode絵文字 : 😀

# %%
print("C:\\test")
# Out:
# C:\test

# %%
print("C:\test")
# Out:
# C:	est

# %%
print("C:r\C:test)
# Out:
#   File "/tmp/ipython-input-26-500514973.py", line 1
#     print("C:r\C:test)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("C:r\C:test")
# Out:
# C:r\C:test

# %%
print("C:\test")
# Out:
# C:	est

# %%
print("C:r\test")
# Out:
# C:r	est

# %%
print("C:\rtest")
# Out:
# test

# %%
print("\rC:test")
# Out:
# C:test

# %%
print("\rC:\test")
# Out:
# C:	est

# %%
print(r'C:\test')
# Out:
# C:\test

# %%
print("ダブルクォート : She said \"Hello\"")
# Out:
# ダブルクォート : She said "Hello"

# %%
print("ダブルクォート : She said \"Hello\"")
# Out:
# ダブルクォート : She said "Hello"

# %%
print(r"ダブルクォート : She said "Hello"")
# Out:
#   File "/tmp/ipython-input-37-4282903176.py", line 1
#     print(r"ダブルクォート : She said "Hello"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(r'ダブルクォート : She said "Hello\"')
# Out:
# ダブルクォート : She said "Hello\"

# %%
print(r'ダブルクォート : She said "Hello"')
# Out:
# ダブルクォート : She said "Hello"

# %%
name = "Python"
print(f"Hello, name!")
# Out:
# Hello, name!

# %%
print(f"Hello," name")
# Out:
#   File "/tmp/ipython-input-41-3612441299.py", line 1
#     print(f"Hello," name")
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(f"Hello," name)
# Out:
#   File "/tmp/ipython-input-42-287338184.py", line 1
#     print(f"Hello," name)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(f"Hello," + name)
# Out:
# Hello,Python

# %%
print(f"Hello," + name + "!")
# Out:
# Hello,Python!

# %%
name = "Python"
print(f"Hello," + name + "!")

# %%
name = "Python"
print(f'Hello, {name}!')
# Out:
# Hello, Python!

# %%
print(f'Hello, {take}!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-47-1576701662.py in <cell line: 0>()
# ----> 1 print(f'Hello, {take}!')
#
# NameError: name 'take' is not defined

# %%
import numpy as np

# %%
a = 1
b = 2
x = f'{a}{b}'
print(x)
# Out:
# 12

# %%
x = len('Python')

# %%
print(x)
# Out:
# 6
