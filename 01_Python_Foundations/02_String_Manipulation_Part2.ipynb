# %%
x = 'Python'
print(x[:2)
# Out:
#   File "/tmp/ipython-input-1-3640555402.py", line 2
#     print(x[:2)
#               ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
x = 'Python'
print(x[:2])
# Out:
# Py

# %%
print(x[4])
# Out:
# o

# %%
print('x[4]', x[4])
# Out:
# x[4] o

# %%
print(x[-2])
# Out:
# o

# %%
print(x[-1])
# Out:
# n

# %%
print(x[0])
# Out:
# P

# %%
print(x[5])
# Out:
# n

# %%
print(x[-6])
# Out:
# P

# %%
print(x[3:-2])
# Out:
# h

# %%
print(x[3:-1])
# Out:
# ho

# %%
n = None
print(n)
# Out:
# None

# %%
a = 10
b = 3.14
c = 'Hello, Python!'
d = True

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# bool

# %%
print(type(a))
# Out:
# <class 'int'>
