# %%
lst = [1, 2, 3]

# %%
print(lst)
# Out:
# [1, 2, 3]

# %%
print(lst[0])
# Out:
# 1

# %%
print(lst[1])
# Out:
# 2

# %%
print(lst[2])
# Out:
# 3

# %%
x = [1, 2, 3]
print(x[0:1])
# Out:
# [1]

# %%
print(x[:2])
# Out:
# [1, 2]

# %%
print(x[2])
# Out:
# 3

# %%
y = ['P', 'y', 't', 'h', 'o', 'n']
print(y[0])
print(y[1])
print(y[2])
print(y[3])
print(y[-2])
# Out:
# P
# y
# t
# h
# o

# %%
y = [1, 2, 3]
y.append(4)

print(y)
# Out:
# [1, 2, 3, 4]

# %%
y.append(4)

# %%
print(y.append(5))
# Out:
# None

# %%
print(y)
# Out:
# [1, 2, 3, 4, 4, 5]

# %%
def five(x):
  x = 5
  return x
  print(five(3))

# %%
def five(x):
  x = 5
  return x
print(five(3))
# Out:
# 5

# %%
def five(x):
  x = 5
  return x

print(five(3))
# Out:
# 5

# %%
10 == 20 / 2
# Out:
# True

# %%
x = live
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1772174783.py in <cell line: 0>()
# ----> 1 x = live
#
# NameError: name 'live' is not defined

# %%
x = 'live'

# %%
y = 'li' + 've'

# %%
y
# Out:
# 'live'

# %%
x == y
# Out:
# True

# %%
10 != 10
# Out:
#   File "/tmp/ipython-input-171751322.py", line 1
#     10 ! = 10
#        ^
# SyntaxError: invalid syntax

# %%
10 != 10
# Out:
# False

# %%
10 != 19
# Out:
# True

# %%
100 > 48
# Out:
# True

# %%
1909 < 44
# Out:
# False

# %%
129 >= 34
# Out:
# True

# %%
18 >= 10+8
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
true and false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3032672724.py in <cell line: 0>()
# ----> 1 true and false
#
# NameError: name 'true' is not defined

# %%
True or false
# Out:
# True

# %%
true and true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1581094950.py in <cell line: 0>()
# ----> 1 true and true
#
# NameError: name 'true' is not defined

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
Ture or false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3854265240.py in <cell line: 0>()
# ----> 1 Ture or false
#
# NameError: name 'Ture' is not defined

# %%
True or false
# Out:
# True

# %%
false and false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2856957099.py in <cell line: 0>()
# ----> 1 false and false
#
# NameError: name 'false' is not defined

# %%
not True
# Out:
# False

# %%
not Flase
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1557285642.py in <cell line: 0>()
# ----> 1 not Flase
#
# NameError: name 'Flase' is not defined

# %%
not False
# Out:
# True

# %%
3 > 5 and 10 <= 20
# Out:
# False

# %%
True and not True
# Out:
# False

# %%
False or not True and True

# %%
False and True or True
