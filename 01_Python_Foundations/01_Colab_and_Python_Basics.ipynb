# %%
print("Hello Workd")
# Out:
# Hello Workd

# %%
print(1+4)
# Out:
# 5

# %%
print("The World")
# Out:
# The World

# %%
a = 10
b = 45

# %%
a+b=
# Out:
#   File "<ipython-input-14-4be79a8e5344>", line 1
#     a+b=
#     ^
# SyntaxError: cannot assign to expression

# %%
x = a + b
print(x)
# Out:
# 55

# %%
y = a * b
print(y)
# Out:
# 450

# %%
import numpy as np
a = np.array([1,2,3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
print(a)
# Out:
# [1 2 3]

# %%
import numpy as np

# %%
a = np.array([1,4,5])

# %%
a
# Out:
# array([1, 4, 5])

# %%
print(a)
# Out:
# [1 4 5]
